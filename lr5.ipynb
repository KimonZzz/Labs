# %% [markdown]
# ### Лабораторная работа №5

# %% [markdown]
# Для произвольного предложения или текста решите следующие задачи:
#
# Токенизация.
# <br>Частеречная разметка.
# <br>Лемматизация.
# <br>Выделение (распознавание) именованных сущностей.
# <br>Разбор предложения.

# %%
text = 'Мы с Холмсом, два холостяка, жили тогда вместе на Бейкер-стрит. Вероятно, я бы и раньше опубликовал свои записи, но я дал слово держать это дело в тайне и освободился от своего слова лишь месяц назад, после безвременной кончины той женщины, которой оно было дано.'

# %% [markdown]
# ### <u>Токенизация

# %%
#!pip3 install -U spacy

# %%
# !python3 -m spacy download ru_core_news_sm
# Out:
# ...
#      |████████████████████████████████| 17.9 MB 7.4 MB/s eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
# !spacy download ru_core_news_sm
# Out:
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.0.0/ru_core_news_sm-3.0.0-py3-none-any.whl (17.9 MB)
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
from spacy.lang.ru import Russian
import spacy
nlp = spacy.load('ru_core_news_sm')
spacy_text = nlp(text)
spacy_text
# Out:
# Мы с Холмсом, два холостяка, жили тогда вместе на Бейкер-стрит. Вероятно, я бы и раньше опубликовал свои записи, но я дал слово держать это дело в тайне и освободился от своего слова лишь месяц назад, после безвременной кончины той женщины, которой оно было дано.

# %%
for t in spacy_text:
    print(t)
# Out:
# Мы
# с
# Холмсом
# ,
# два
# холостяка
# ,
# жили
# тогда
# вместе
# на
# Бейкер
# -
# стрит
# .
# Вероятно
# ,
# я
# бы
# и
# раньше
# опубликовал
# свои
# записи
# ,
# но
# я
# дал
# слово
# держать
# это
# дело
# в
# тайне
# и
# освободился
# от
# своего
# слова
# лишь
# месяц
# назад
# ,
# после
# безвременной
# кончины
# той
# женщины
# ,
# которой
# оно
# было
# дано
# .

# %% [markdown]
# ### <u>Частеречная разметка

# %%
for token in spacy_text:
    print('{} - {} - {}'.format(token.text, token.pos_, token.dep_))
# Out:
# Мы - PRON - nsubj
# с - ADP - case
# Холмсом - PROPN - nmod
# , - PUNCT - punct
# два - NUM - nummod:gov
# холостяка - NOUN - conj
# , - PUNCT - punct
# жили - VERB - ROOT
# тогда - ADV - advmod
# вместе - ADV - advmod
# на - ADP - case
# Бейкер - PROPN - obl
# - - PROPN - obl
# стрит - PROPN - obl
# . - PUNCT - punct
# Вероятно - ADV - parataxis
# , - PUNCT - punct
# я - PRON - nsubj
# бы - AUX - aux
# и - PART - advmod
# раньше - ADV - advmod
# опубликовал - VERB - ROOT
# свои - DET - det
# записи - NOUN - obj
# , - PUNCT - punct
# но - CCONJ - cc
# я - PRON - nsubj
# дал - VERB - conj
# слово - NOUN - obj
# держать - VERB - xcomp
# это - DET - det
# дело - NOUN - obj
# в - ADP - case
# тайне - NOUN - obl
# и - CCONJ - cc
# освободился - VERB - conj
# от - ADP - case
# своего - DET - det
# слова - NOUN - obl
# лишь - PART - advmod
# месяц - NOUN - obl
# назад - ADV - advmod
# , - PUNCT - punct
# после - ADP - case
# безвременной - ADJ - amod
# кончины - NOUN - conj
# ...

# %% [markdown]
# ### <u>Лемматизация.

# %%
for token in spacy_text:
      print(token, token.lemma, token.lemma_)
# Out:
# Мы 8265924134616824262 мы
# с 5863529159893111856 с
# Холмсом 4140266199296507159 холмс
# , 2593208677638477497 ,
# два 15400399964508618332 два
# холостяка 5556030863238616633 холостяк
# , 2593208677638477497 ,
# жили 8359082292689204631 жить
# тогда 939218841526046008 тогда
# вместе 11512671680799693093 вместе
# на 16191904166009283104 на
# Бейкер 356512423996754283 бейкер
# - 9153284864653046197 -
# стрит 16534252444072921901 стрит
# . 12646065887601541794 .
# Вероятно 14915128188499539458 вероятно
# , 2593208677638477497 ,
# я 12329462409828574123 я
# бы 5478479325712016621 бы
# и 15015917632809974589 и
# раньше 1087194605925455389 раньше
# опубликовал 7665409113326668452 опубликовать
# свои 12292881551881158589 свой
# записи 16209021793679437720 запись
# , 2593208677638477497 ,
# но 14653780147686393572 но
# я 12329462409828574123 я
# дал 5296159030628747847 дать
# слово 1386213856741127517 слово
# держать 2764607011323848682 держать
# это 13138259693353519549 этот
# ...

# %% [markdown]
# ### <u>Выделение (распознавание) именованных сущностей.

# %%
for ent in spacy_text.ents:
    print(ent.text, ent.label_)
# Out:
# Холмсом PER
# Бейкер-стрит LOC

# %%
from spacy import displacy
displacy.render(spacy_text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Мы с
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Холмсом
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , два холостяка, жили тогда вместе на
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Бейкер-стрит
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Вероятно, я бы и раньше опубликовал свои записи, но я дал слово держать это дело в тайне и освободился от своего слова лишь месяц назад, после безвременной кончины той женщины, которой оно было дано.</div></span>

# %%
print(spacy.explain("LOC"))
# Out:
# Non-GPE locations, mountain ranges, bodies of water

# %%
print(spacy.explain("PER"))
# Out:
# Named person or family.

# %% [markdown]
# ### <u>Разбор предложения.

# %%
from spacy import displacy

# %%
displacy.render(spacy_text, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="b369114018a24573ad6a21dba5f5034c-0" class="displacy" width="7925" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Мы</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">с</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...
